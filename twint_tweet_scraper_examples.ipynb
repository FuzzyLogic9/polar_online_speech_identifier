# %%
# pip install twint module from its repo
! pip3 install --user --upgrade git+https://github.com/twintproject/twint.git@origin/master#egg=twint
# Out:
# ...
#   Cloning https://github.com/twintproject/twint.git (to revision origin/master) to /tmp/pip-install-9sgq22ya/twint
#   Running command git clone -q https://github.com/twintproject/twint.git /tmp/pip-install-9sgq22ya/twint
#   WARNING: Did not find branch or tag 'origin/master', assuming revision or ref.
#   Running command git checkout -q origin/master
# ...
#      |████████████████████████████████| 1.2MB 3.3MB/s
# ...
#      |████████████████████████████████| 245kB 20.4MB/s
# ...
#      |████████████████████████████████| 225kB 20.2MB/s
# ...
#      |████████████████████████████████| 153kB 19.5MB/s
# ...
#      |████████████████████████████████| 266kB 22.3MB/s
# ...
#      |████████████████████████████████| 235kB 24.0MB/s
# ...
#      |████████████████████████████████| 81kB 10.4MB/s
# ...
#   Created wheel for twint: filename=twint-2.1.21-cp36-none-any.whl size=39457 sha256=6811971e910ca614e2e9e7f38c24ba45de1b612774b61043187b481c316f3db9
# ...

# %%
## There are known issues running twint in jupyter, nest_asyncio may be able to solve the problem. 
## When in an environment where the event loop is already running it’s impossible to run tasks and wait for the result.
## nest_asyncio may solve this problem
 
! pip install nest_asyncio

# %%
# If working on google.colab, these code would be useful for mounting to your own google drive. 
# Otherwise, anything that is saved within Google Colab environment will be deleted at the end of each session

from google.colab import drive
drive.mount('/content/drive')

# %%
import twint

import nest_asyncio
nest_asyncio.apply()

# %%
#configuration   
#check twint wiki for more config options

config = twint.Config()
#config.Username = "guardian"
#config.User_Id = '87818409'
config.Search = "black lives matter"

config.Lang = "en"
config.Limit = 200
config.Since = "2020-05-20 00:00:00"
config.Until = "2020-06-10 23:59:00"
#config.Store_pandas = True    #the Store_csv option doesn't work very well
#config.Output = "blm_tweets.txt"

config.Store_json = True
config.Output = "blm_tweets.json"
#config.Geo = "48.880048,2.385939,10km."

#running search
twint.run.Search(config)
# Out:
# 1318916398287101953 2020-10-21 14:05:48 +0000 <dvan_toor> @DonaldJTrumpJr @EricTrump @realDonaldTrump LIE! Our fight against human trafficking is one of the great human rights causes of our time, and the United States will continue to lead it ... worthy of 'the considerate judgment of mankind, and the gracious favor of Almighty God'. President Barack Obama  https://t.co/wRJ2tUGvjt
# 1318916375763562496 2020-10-21 14:05:42 +0000 <Pathom3333> @realDonaldTrump Little Donnie, who is this for? Maybe you and your rich friends? Maybe you'll pay another $750? SMDH. My grandkid's great-grandkids will still be paying for the tax cut you gave your buddies. Orange is definitely your color.  https://t.co/HE8nfhnl7Z
# 1318916327243804673 2020-10-21 14:05:31 +0000 <GreatPrestoni> @realDonaldTrump Liar
# ...
